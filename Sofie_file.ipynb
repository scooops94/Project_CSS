# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from census import Census

# Census API Key
from config import api_key
c = Census(api_key, year=2017)

# %%
census_data = c.acs5.get(("NAME","B23025_004E", "B23025_005E", "B23025_006E", "C24010_003E", "C24010_004E", "C24010_006E","C24010_007E", "C24010_008E", "C24010_009E", "C24010_010E", "C24010_011E","C24010_012E", "C24010_013E","C24010_014E", "C24010_015E", "C24010_016E", "C24010_017E", "C24010_018E", "C24010_019E", "C24010_020E", "C24010_021E", "C24010_022E", "C24010_023E", "C24010_024E", "C24010_025E", "C24010_026E", "C24010_027E", "C24010_028E", "C24010_029E", "C24010_030E", "C24010_031E", "C24010_032E", "C24010_033E", "C24010_034E","C24010_035E", "C24010_036E", "C24010_037E"), {'for': 'state:*'})
census_pd = pd.DataFrame(census_data)
census_pd = census_pd.rename(columns={"NAME": "Name",
                                      "B23025_004E": "Employed",
                                      "B23025_005E": "Unemployed",
                                     "B23025_006E": "Armed Forces",
                                     "C24010_003E": "Men in Management, Business, Science, or the Arts",
                                     "C24010_004E": "Men in Management Occupations",
                                      "C24010_006E": "Men in Business and Financial Operations",
                                      "C24010_007E" :"Men in Computer, Engineering, or Science",
                                      "C24010_008E" : "Men in Computer and Mathematical",
                                      "C24010_009E" : "Men in Architecture and Engineering",
                                      "C24010_010E" : "Men in Life, Physical, or Social Science",
                                      "C24010_011E" : "Men in Education, Legal, Community Service, Arts, or Media",
                                      "C24010_012E" : "Men in Community and Social Seervice",
                                      "C24010_013E" : "Men in Legal Occupations",
                                      "C24010_014E" : "Men in Education, Training, or Library Occupations",
                                      "C24010_015E" : "Men in Arts, Design, Entertainment, Sports, or Media Occupations",
                                      "C24010_016E" : "Men in Healthcare Practitioners and Technical Occupations",
                                      "C24010_017E" : "Men in Health Diagnosing and Treating Practitioners and Other Technical Occupations",
                                      "C24010_018E" : "Health technologists and technicians",
                                      "C24010_019E" : "Service occupations",
                                      "C24010_020E" : "Healthcare support occupations",
                                      "C24010_021E" : "Protective service occupations",
                                      "C24010_022E" : "Fire fighting and prevention, or other protective service workers including supervisors",
                                      "C24010_023E" : "Law enforcement workers including supervisors",
                                      "C24010_024E" : "Food preparation and serving related occupations",
                                      "C24010_025E" : "Building and grounds cleaning and maintenance occupations",
                                      "C24010_026E" : "Personal care and service occupations",
                                      "C24010_027E" : "Sales and office occupations",
                                      "C24010_028E" : "Sales and related occupations",
                                      "C24010_029E" : "Office and administrative support occupations",
                                      "C24010_030E" : "Natural resources, construction, or maintenance occupations",
                                      "C24010_031E" : "Farming, fishing, or forestry occupations",
                                      "C24010_032E" : "Construction and extraction occupations",
                                      "C24010_033E" : "Installation, maintenance, or repair occupations",
                                      "C24010_034E" : "Production, transportation, or material moving occupations",
                                      "C24010_035E" : "Production occupations",
                                      "C24010_036E" : "Transportation occupations",
                                      "C24010_037E" : "Material moving occupations"
                                      })
census_pd.set_index("Name", inplace=True)
census_pd
# Out:
#                         Employed  Unemployed  Armed Forces  \
# Name
# Puerto Rico            1040136.0    220597.0        1487.0
# Alabama                2055509.0    165391.0       12309.0
# Alaska                  354045.0     29548.0       17029.0
# Arizona                2953891.0    225911.0       17314.0
# Arkansas               1276536.0     85128.0        4438.0
# California            17993915.0   1491146.0      127716.0
# Colorado               2760076.0    152856.0       33422.0
# Connecticut            1805086.0    140712.0        8566.0
# District of Columbia    357701.0     31279.0        3441.0
# Delaware                441513.0     30245.0        3016.0
# Florida                9018570.0    699117.0       55075.0
# Georgia                4606329.0    372581.0       47396.0
# Hawaii                  671758.0     34380.0       40302.0
# Idaho                   748658.0     42328.0        3676.0
# Illinois               6181653.0    491310.0       17232.0
# ...

# %%
census_pd_transposed = census_pd.T
census_pd_transposed
# Out:
# Name                                                Puerto Rico      Alabama  \
# Employed                                            1.04014e+06  2.05551e+06
# Unemployed                                               220597       165391
# Armed Forces                                               1487        12309
# Men in Management, Business, Science, or the Arts        136355       318846
# Men in Management Occupations                             59493       143420
# Men in Business and Financial Operations                  21166        33527
# Men in Computer, Engineering, or Science                  21732        73666
# Men in Computer and Mathematical                           7741        29673
# Men in Architecture and Engineering                       10245        36518
# Men in Life, Physical, or Social Science                   3746         7475
# Men in Education, Legal, Community Service, Art...        36422        70700
# ...

# %%
census_data_female = c.acs5.get(("NAME","B23025_004E", "B23025_005E", "C24010_039E","C24010_040E","C24010_041E", "C24010_042E","C24010_043E", "C24010_044E", "C24010_045E", "C24010_046E", "C24010_047E", "C24010_048E", "C24010_049E", "C24010_050E","C24010_051E", "C24010_052E", "C24010_053E", "C24010_054E", "C24010_055E", "C24010_056E","C24010_057E", "C24010_058E", "C24010_059E", "C24010_060E", "C24010_061E", "C24010_062E", "C24010_063E", "C24010_064E", "C24010_065E", "C24010_066E", "C24010_067E", "C24010_068E", "C24010_069E", "C24010_070E", "C24010_071E", "C24010_072E", "C24010_073E",   ), {'for': 'state:*'})
census_pd_female = pd.DataFrame(census_data_female)
census_pd_female = census_pd_female.rename(columns={"NAME": "Name",
                                      "B23025_004E": "Employed",
                                      "B23025_005E": "Unemployed",
                                    "C24010_039E" : "Management, business, science, or arts occupations",
                                    "C24010_040E" : "Management, business, or financial occupations:",
                                    "C24010_041E" : "Management occupations",
                                    "C24010_042E" : "Business and financial operations occupations",
                                    "C24010_043E" : "Computer, engineering, or science occupations",
                                    "C24010_044E" : "Computer and mathematical occupations",
                                    "C24010_045E" : "Architecture and engineering occupations",
                                    "C24010_046E" : "Life, physical, or social science occupations",
                                    "C24010_047E" : "Education, legal, community service, arts, or media occupations",
                                    "C24010_048E" : "Community and social service occupations",
                                    "C24010_049E" : "Legal occupations",
                                    "C24010_050E" : "Education, training, or library occupations",
                                    "C24010_051E" : "Arts, design, entertainment, sports, or media occupations",
                                    "C24010_052E" : "Healthcare practitioners and technical occupations",
                                    "C24010_053E" : "Health diagnosing and treating practitioners and other technical occupations",
                                    "C24010_054E" : "Health technologists and technicians",
                                    "C24010_055E" : "Service occupations",
                                    "C24010_056E" : "Healthcare support occupations",
                                    "C24010_057E" : "Protective service occupations",
                                    "C24010_058E" : "Fire fighting and prevention, or other protective service workers including supervisors",
                                    "C24010_059E" : "Law enforcement workers including supervisors",
                                    "C24010_060E" : "Food preparation and serving related occupations",
                                    "C24010_061E" : "Building and grounds cleaning and maintenance occupations",
                                    "C24010_062E" : "Personal care and service occupations",
                                    "C24010_063E" : "Sales and office occupations",
                                    "C24010_064E" : "Sales and related occupations",
                                    "C24010_065E" : "Office and administrative support occupations",
                                    "C24010_066E" : "Natural resources, construction, or maintenance occupations",
                                    "C24010_067E" : "Farming, fishing, or forestry occupations",
                                    "C24010_068E" : "Construction and extraction occupations",
                                    "C24010_069E" : "Installation, maintenance, or repair occupations",
                                    "C24010_070E" : "Production, transportation, or material moving occupations",
                                    "C24010_071E" : "Production occupations",
                                    "C24010_072E" : "Transportation occupations",
                                    "C24010_073E" : "Material moving occupations"
                                    })

census_pd_female.set_index("Name", inplace=True)
census_pd_female
# Out:
#                         Employed  Unemployed  \
# Name
# Puerto Rico            1040136.0    220597.0
# Alabama                2055509.0    165391.0
# Alaska                  354045.0     29548.0
# Arizona                2953891.0    225911.0
# Arkansas               1276536.0     85128.0
# California            17993915.0   1491146.0
# Colorado               2760076.0    152856.0
# Connecticut            1805086.0    140712.0
# District of Columbia    357701.0     31279.0
# Delaware                441513.0     30245.0
# Florida                9018570.0    699117.0
# Georgia                4606329.0    372581.0
# Hawaii                  671758.0     34380.0
# Idaho                   748658.0     42328.0
# Illinois               6181653.0    491310.0
# Indiana                3124295.0    202199.0
# Iowa                   1599718.0     69018.0
# Kansas                 1420045.0     71009.0
# Kentucky               1938150.0    140717.0
# Maine                   658693.0     36790.0
# ...

# %%
census_pd_female_transposed = census_pd_female.T
census_pd_female_transposed
# Out:
# Name                                                Puerto Rico      Alabama  \
# Employed                                            1.04014e+06  2.05551e+06
# Unemployed                                               220597       165391
# Management, business, science, or arts occupations       200251       381482
# Management, business, or financial occupations:           63890       118937
# Management occupations                                    35674        71486
# Business and financial operations occupations             28216        47451
# Computer, engineering, or science occupations             11936        23163
# Computer and mathematical occupations                      3279        12308
# Architecture and engineering occupations                   2980         6344
# Life, physical, or social science occupations              5677         4511
# Education, legal, community service, arts, or m...        78476       135320
# ...
